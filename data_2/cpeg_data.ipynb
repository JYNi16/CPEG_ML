# %%
import pandas as pd 
import xlrd
from xlrd import open_workbook

# %%
xls = pd.ExcelFile('D:\CPEG\data_2\TCPGE_data.xlsx')

# %%
xls.sheet_names
# Out:
# ['X', 'Y', 'Z', 'XY', 'XZ', 'YZ', 'XYZ', 'Sheet2']

# %%
data_x = pd.read_excel(xls, sheet_name="X")

# %%
data_x
# Out:
#              X  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0   D=(a'-a)/a   -0.030000   -0.029000   -0.028000   -0.027000   -0.026000
# 1        v^t_x    0.766192    0.760761    0.754821    0.743964    0.742577
# 2        v^t_y    0.609807    0.605057    0.599857    0.603324    0.592645
# 3        v^t_z   -0.314216   -0.314882   -0.313587   -0.333691   -0.330207
# 4          v_x    0.694818    0.694070    0.694740    0.716945    0.711458
# 5          v_y    0.545896    0.546730    0.545951    0.540711    0.541798
# 6          v_z   -0.526147    0.522549    0.524165    0.533857    0.536454
# 7          d_x   -5.542581   -4.169244   -2.738580   -2.252581   -0.912202
# 8          d_y    3.224761    1.738236   -0.223565    1.644895   -0.823094
# 9          d_z   -0.568188   -0.244564   -1.643217    3.130360    0.453258
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
data_x["Unnamed: 1"][0]
# Out:
# -0.03

# %%
data_x.shape[1]
# Out:
# 62

# %%
for i in range(data_x.shape[0]):
    val = [] 
    for j in range(data_x.shape[1]):
        print(data_x.value)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 4
#       2 val = []
#       3 for j in range(data_x.shape[1]):
# ----> 4     print(data_x.value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'value'
